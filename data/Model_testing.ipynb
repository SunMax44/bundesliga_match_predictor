# %%
#Libraries
import numpy as np
from sklearn.model_selection import train_test_split

from sklearn.preprocessing import MinMaxScaler, StandardScaler

from sklearn.neighbors import KNeighborsRegressor
from sklearn.neighbors import KNeighborsClassifier

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import DecisionTreeRegressor

from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

import pandas as pd
import glob
import os
import re

# %%
# Specify the folder path where CSV files are stored
folder_path = 'data/'

# Use glob to find all CSV files in the specified folder
all_files = glob.glob(os.path.join(folder_path, "*.csv"))

# Use a list comprehension to read each CSV file into a DataFrame and ensure 'Date' is string
df_list = []
for file in all_files:
    try:
        # Read each CSV and convert 'Date' to string format
        buli_df = pd.read_csv(file, encoding='ISO-8859-1', dtype={'Date': str})
        df_list.append(buli_df)
    except pd.errors.ParserError as e:
        print(f"ParserError parsing {file}: {e}")
    except UnicodeDecodeError as e:
        print(f"UnicodeDecodeError in {file}: {e}")

# Concatenate all DataFrames in the list into a single DataFrame
buli_df = pd.concat(df_list, ignore_index=True)

# Standardize and parse the 'Date' column
buli_df['Date'] = buli_df['Date'].str.strip()  # Remove extra whitespace
buli_df['Date'] = buli_df['Date'].replace(r'[/-]', '-', regex=True)  # Replace separators with '-'

# Attempt to parse dates as `dayfirst` and handle both `dd/mm/yyyy` and `dd/mm/yy`
buli_df['Date'] = buli_df['Date'].apply(lambda x: re.sub(r'(\d{2}/\d{2}/)(\d{2})$', r'\120\2', x))
buli_df['Date'] = pd.to_datetime(buli_df['Date'], dayfirst=True, errors='coerce')

# Check for any remaining NaT values in 'Date' after parsing
missing_dates = buli_df[buli_df['Date'].isna()]
if not missing_dates.empty:
    print("Warning: Some dates could not be parsed after concatenation.")
    print(missing_dates)

# Display the combined DataFrame
print("Final combined DataFrame with parsed dates:")
buli_df
# Out:
# Final combined DataFrame with parsed dates:
# /var/folders/gk/c2gpqh3x7z74jf883m6p8r3c0000gn/T/ipykernel_75926/4226996146.py:34: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   buli_df['Date'] = pd.to_datetime(buli_df['Date'], dayfirst=True, errors='coerce')
#      Div       Date       HomeTeam            AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0     D1 2015-08-14  Bayern Munich             Hamburg     5     0   H     1
# 1     D1 2015-08-15       Augsburg              Hertha     0     1   A     0
# 2     D1 2015-08-15      Darmstadt            Hannover     2     2   D     1
# 3     D1 2015-08-15       Dortmund          M'gladbach     4     0   H     3
# 4     D1 2015-08-15     Leverkusen          Hoffenheim     2     1   H     1
# ...   ..        ...            ...                 ...   ...   ...  ..   ...
# 5575  D1 2013-05-18        Hamburg          Leverkusen     0     1   A     0
# 5576  D1 2013-05-18       Hannover  Fortuna Dusseldorf     3     0   H     1
# 5577  D1 2013-05-18     M'gladbach       Bayern Munich     3     4   A     3
# 5578  D1 2013-05-18       Nurnberg       Werder Bremen     3     2   H     0
# 5579  D1 2013-05-18      Stuttgart               Mainz     2     2   D     2
#
#       HTAG HTR  ...  BFECAHA  IWCH  IWCD  IWCA  VCCH  VCCD  VCCA  Unnamed: 70  \
# 0        0   H  ...      NaN   NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 1        0   D  ...      NaN   NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 2        0   H  ...      NaN   NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 3        0   H  ...      NaN   NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 4        1   D  ...      NaN   NaN   NaN   NaN   NaN   NaN   NaN          NaN
# ...    ...  ..  ...      ...   ...   ...   ...   ...   ...   ...          ...
# 5575     0   D  ...      NaN   NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 5576     0   H  ...      NaN   NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 5577     2   H  ...      NaN   NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 5578     1   A  ...      NaN   NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 5579     2   D  ...      NaN   NaN   NaN   NaN   NaN   NaN   NaN          NaN
#
#       Unnamed: 71  Unnamed: 72
# 0             NaN          NaN
# 1             NaN          NaN
# 2             NaN          NaN
# 3             NaN          NaN
# 4             NaN          NaN
# ...           ...          ...
# 5575          NaN          NaN
# 5576          NaN          NaN
# 5577          NaN          NaN
# 5578          NaN          NaN
# 5579          NaN          NaN
#
# [5580 rows x 168 columns]

# %%
#formatting the date column to datetime format and sorting by date
#buli_df['Date'] = pd.to_datetime(buli_df['Date'])

buli_df = buli_df.sort_values(['Date']).reset_index(drop=True)
buli_df
# Out:
#       Div       Date       HomeTeam       AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0      D1 2006-08-11  Bayern Munich       Dortmund     2     0   H     1
# 1      D1 2006-08-12     Leverkusen         Aachen     3     0   H     2
# 2      D1 2006-08-12          Mainz         Bochum     2     1   H     1
# 3      D1 2006-08-12     M'gladbach        Cottbus     2     0   H     0
# 4      D1 2006-08-12     Schalke 04  Ein Frankfurt     1     1   D     1
# ...   ...        ...            ...            ...   ...   ...  ..   ...
# 5575  NaN 2024-10-26       St Pauli      Wolfsburg     0     0   D     0
# 5576  NaN 2024-10-26     RB Leipzig       Freiburg     3     1   H     0
# 5577  NaN 2024-10-27     Heidenheim     Hoffenheim     0     0   D     0
# 5578  NaN 2024-10-27   Union Berlin  Ein Frankfurt     1     1   D     0
# 5579  NaN 2024-10-27         Bochum  Bayern Munich     0     5   A     0
#
#       HTAG HTR  ...  BFECAHA  IWCH  IWCD  IWCA  VCCH  VCCD  VCCA  Unnamed: 70  \
# 0        0   H  ...      NaN   NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 1        0   H  ...      NaN   NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 2        0   H  ...      NaN   NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 3        0   D  ...      NaN   NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 4        0   H  ...      NaN   NaN   NaN   NaN   NaN   NaN   NaN          NaN
# ...    ...  ..  ...      ...   ...   ...   ...   ...   ...   ...          ...
# 5575     0   D  ...     2.08   NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 5576     1   A  ...     1.90   NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 5577     0   D  ...     1.93   NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 5578     1   A  ...     2.25   NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 5579     2   A  ...     2.08   NaN   NaN   NaN   NaN   NaN   NaN          NaN
#
#       Unnamed: 71  Unnamed: 72
# 0             NaN          NaN
# 1             NaN          NaN
# 2             NaN          NaN
# 3             NaN          NaN
# 4             NaN          NaN
# ...           ...          ...
# 5575          NaN          NaN
# 5576          NaN          NaN
# 5577          NaN          NaN
# 5578          NaN          NaN
# 5579          NaN          NaN
#
# [5580 rows x 168 columns]

# %%
#checking for null values
buli_df.isna().sum()
# Out:
# Div              72
# Date              0
# HomeTeam          0
# AwayTeam          0
# FTHG              0
#                ...
# VCCD           4050
# VCCA           4050
# Unnamed: 70    5580
# Unnamed: 71    5580
# Unnamed: 72    5580
# Length: 168, dtype: int64

# %%
#dropping rows & columns with all null values
buli_df.dropna(axis=1, how='all', inplace=True) #dropped 3 columns
buli_df.dropna(axis=0, how='all',inplace=True) #0 rows dropped

# %%
buli_df.isna().sum()
# Out:
# Div           72
# Date           0
# HomeTeam       0
# AwayTeam       0
# FTHG           0
#             ...
# IWCD        4223
# IWCA        4223
# VCCH        4050
# VCCD        4050
# VCCA        4050
# Length: 165, dtype: int64

# %%
#code for including all games (first games of the season take the last games of the last season as past games)

import pandas as pd

buli_df_red = buli_df[['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HTHG', 'HTAG', 'HTR', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC', 'AC', 'HY', 'AY', 'HR', 'AR']]

df = buli_df_red

# Define stats dictionary with the specified columns
stats = {
    'goals': {'scored': ('FTHG', 'FTAG'), 'conceded': ('FTAG', 'FTHG')},
    'shots': {'taken': ('HS', 'AS'), 'conceded': ('AS', 'HS')},
    'shots_on_target': {'taken': ('HST', 'AST'), 'conceded': ('AST', 'HST')},
    'fouls': {'fouls': ('HF', 'AF'), 'fouled': ('AF', 'HF')},
    'corners': {'taken': ('HC', 'AC'), 'conceded': ('AC', 'HC')},
    'yellow_cards': {'received': ('HY', 'AY'), 'provoked': ('AY', 'HY')},
    'red_cards': {'received': ('HR', 'AR'), 'provoked': ('AR', 'HR')},
}

# Define `npm` for the number of past matches to consider
npm = 7

# Initialize an empty list to accumulate each row's data as a dictionary
rows_list = []

# Iterate through each row to calculate rolling stats based on home and away perspectives
for index, row in df.iterrows():
    team_h = row['HomeTeam']
    team_a = row['AwayTeam']
    date = row['Date']
    
    # Get the past `npm` games for the home team, filtered by games before the current match date
    past_matches_home = df[((df['HomeTeam'] == team_h) | (df['AwayTeam'] == team_h)) & (df['Date'] < date)]
    past_matches_home = past_matches_home.tail(npm)

    # Get the past `npm` games for the away team, filtered by games before the current match date
    past_matches_away = df[((df['HomeTeam'] == team_a) | (df['AwayTeam'] == team_a)) & (df['Date'] < date)]
    past_matches_away = past_matches_away.tail(npm)

    # Initialize a dictionary to store the calculated stats for each row
    row_stats = {
        'Date': date,
        'HomeTeam': team_h,
        'AwayTeam': team_a,
        'FTR': row['FTR'],
        'FTHG': row['FTHG'],
        'FTAG': row['FTAG'],
    }
    
    # Calculate stats for the home team based on whether they played home or away in past matches
    for stat, subcategories in stats.items():
        for subcategory, columns in subcategories.items():
            home_column, away_column = columns
            # Sum the stat when the home team was actually playing at home
            stat_home_as_home = past_matches_home.loc[past_matches_home['HomeTeam'] == team_h, home_column].sum()
            # Sum the stat when the home team was actually playing as the away team
            stat_home_as_away = past_matches_home.loc[past_matches_home['AwayTeam'] == team_h, away_column].sum()
            row_stats[f'p_home_{stat}_{subcategory}_last_{npm}'] = stat_home_as_home + stat_home_as_away
            
    # Calculate stats for the away team based on whether they played home or away in past matches
    for stat, subcategories in stats.items():
        for subcategory, columns in subcategories.items():
            home_column, away_column = columns
            # Sum the stat when the away team was actually playing at home
            stat_away_as_home = past_matches_away.loc[past_matches_away['HomeTeam'] == team_a, home_column].sum()
            # Sum the stat when the away team was actually playing as the away team
            stat_away_as_away = past_matches_away.loc[past_matches_away['AwayTeam'] == team_a, away_column].sum()
            row_stats[f'p_away_{stat}_{subcategory}_last_{npm}'] = stat_away_as_home + stat_away_as_away

    # Calculate points for the home team in the past `npm` games
    points_home = (
        (past_matches_home.loc[past_matches_home['HomeTeam'] == team_h, 'FTR'] == 'H').sum() * 3 +
        (past_matches_home.loc[past_matches_home['AwayTeam'] == team_h, 'FTR'] == 'A').sum() * 3 +
        (past_matches_home['FTR'] == 'D').sum() * 1
    )
    row_stats[f'p_home_points_last_{npm}'] = points_home
    
    # Calculate points for the away team in the past `npm` games
    points_away = (
        (past_matches_away.loc[past_matches_away['HomeTeam'] == team_a, 'FTR'] == 'H').sum() * 3 +
        (past_matches_away.loc[past_matches_away['AwayTeam'] == team_a, 'FTR'] == 'A').sum() * 3 +
        (past_matches_away['FTR'] == 'D').sum() * 1
    )
    row_stats[f'p_away_points_last_{npm}'] = points_away
    
    # Append the dictionary for this row to the list
    rows_list.append(row_stats)

# Convert the list of dictionaries to a DataFrame
rolling_stats = pd.DataFrame(rows_list)

# Display the final DataFrame with only the desired columns
print("Final DataFrame with selected initial columns and past 7 games stats:")
rolling_stats_with_first_games_of_season = rolling_stats
# Out:
# Final DataFrame with selected initial columns and past 7 games stats:

# %%
rolling_stats_with_first_games_of_season = rolling_stats

# %%
#columns_to_check = ['p_away_goals_conceded_last_7', 'p_away_goals_scored_last_7', 'p_home_corners_conceived_last_7','p_away_corners_conceived_last_7', 'p_home_yellow_cards_received_last_7','p_home_yellow_cards_provoked_last_7','p_away_corners_taken_last_7']
rolling_stats_with_first_games_of_season.loc[5461]
# Out:
# Date                                      2024-04-14 00:00:00
# HomeTeam                                            Darmstadt
# AwayTeam                                             Freiburg
# FTR                                                         A
# FTHG                                                        0
# FTAG                                                        1
# p_home_goals_scored_last_7                                  6
# p_home_goals_conceded_last_7                               22
# p_home_shots_taken_last_7                                  85
# p_home_shots_conceded_last_7                              139
# p_home_shots_on_target_taken_last_7                        29
# p_home_shots_on_target_conceded_last_7                     44
# p_home_fouls_fouls_last_7                                  79
# p_home_fouls_fouled_last_7                                 68
# p_home_corners_taken_last_7                                26
# p_home_corners_conceded_last_7                             41
# p_home_yellow_cards_received_last_7                        19
# p_home_yellow_cards_provoked_last_7                        12
# p_home_red_cards_received_last_7                            0
# p_home_red_cards_provoked_last_7                            1
# p_away_goals_scored_last_7                                 14
# p_away_goals_conceded_last_7                               15
# p_away_shots_taken_last_7                                  81
# p_away_shots_conceded_last_7                              121
# p_away_shots_on_target_taken_last_7                        34
# p_away_shots_on_target_conceded_last_7                     46
# p_away_fouls_fouls_last_7                                  68
# p_away_fouls_fouled_last_7                                 73
# p_away_corners_taken_last_7                                27
# p_away_corners_conceded_last_7                             55
# p_away_yellow_cards_received_last_7                        13
# p_away_yellow_cards_provoked_last_7                        13
# p_away_red_cards_received_last_7                            0
# p_away_red_cards_provoked_last_7                            0
# p_home_points_last_7                                        2
# p_away_points_last_7                                        8
# Name: 5461, dtype: object

# %%
#code for starting every season only with the 8th games, so that every game of the season that is taken into account has
# 7 past games that were played within the very same season

import pandas as pd
import numpy as np

# Sample data setup (make sure 'Date' column is in datetime format)
df['Date'] = pd.to_datetime(df['Date'])

# Step 1: Identify season breaks by detecting gaps of 2 months or more
df = df.sort_values(by='Date').reset_index(drop=True)
df['Date_Diff'] = df['Date'].diff().dt.days
season_breaks = df[df['Date_Diff'] >= 60].index  # Gaps of 60+ days signify a new season

# Step 2: Assign a season identifier
df['Season'] = 0
current_season = 1
for i in range(len(df)):
    if i in season_breaks:
        current_season += 1
    df.at[i, 'Season'] = current_season

# Drop the Date_Diff column as it's no longer needed
df = df.drop(columns=['Date_Diff'])

# Define `npm` for the number of past matches to consider
npm = 7

# Initialize an empty list to accumulate each row's data as a dictionary
rows_list = []

# Iterate through each row to calculate rolling stats based on home and away perspectives
for index, row in df.iterrows():
    team_h = row['HomeTeam']
    team_a = row['AwayTeam']
    date = row['Date']
    
    # Get the past `npm` games for the home team within the same season
    past_matches_home = df[((df['HomeTeam'] == team_h) | (df['AwayTeam'] == team_h)) & 
                           (df['Date'] < date) & 
                           (df['Season'] == row['Season'])]
    past_matches_home = past_matches_home.tail(npm)

    # Get the past `npm` games for the away team within the same season
    past_matches_away = df[((df['HomeTeam'] == team_a) | (df['AwayTeam'] == team_a)) & 
                           (df['Date'] < date) & 
                           (df['Season'] == row['Season'])]
    past_matches_away = past_matches_away.tail(npm)

    # Initialize a dictionary to store the calculated stats for each row
    row_stats = {
        'Date': date,
        'HomeTeam': team_h,
        'AwayTeam': team_a,
        'FTR': row['FTR'],
        'FTHG': row['FTHG'],  # Include Full Time Home Goals directly
        'FTAG': row['FTAG'],  # Include Full Time Away Goals directly
        'Season': row['Season']
    }
    
    # Calculate stats for the home team based on whether they played home or away in past matches
    for stat, subcategories in stats.items():
        for subcategory, columns in subcategories.items():
            home_column, away_column = columns
            # Sum the stat when the home team was actually playing at home
            stat_home_as_home = past_matches_home.loc[past_matches_home['HomeTeam'] == team_h, home_column].sum()
            # Sum the stat when the home team was actually playing as the away team
            stat_home_as_away = past_matches_home.loc[past_matches_home['AwayTeam'] == team_h, away_column].sum()
            row_stats[f'p_home_{stat}_{subcategory}_last_{npm}'] = stat_home_as_home + stat_home_as_away
            
    # Calculate stats for the away team based on whether they played home or away in past matches
    for stat, subcategories in stats.items():
        for subcategory, columns in subcategories.items():
            home_column, away_column = columns
            # Sum the stat when the away team was actually playing at home
            stat_away_as_home = past_matches_away.loc[past_matches_away['HomeTeam'] == team_a, home_column].sum()
            # Sum the stat when the away team was actually playing as the away team
            stat_away_as_away = past_matches_away.loc[past_matches_away['AwayTeam'] == team_a, away_column].sum()
            row_stats[f'p_away_{stat}_{subcategory}_last_{npm}'] = stat_away_as_home + stat_away_as_away

    # Calculate points for the home team in the past `npm` games
    points_home = (
        (past_matches_home.loc[past_matches_home['HomeTeam'] == team_h, 'FTR'] == 'H').sum() * 3 +
        (past_matches_home.loc[past_matches_home['AwayTeam'] == team_h, 'FTR'] == 'A').sum() * 3 +
        (past_matches_home['FTR'] == 'D').sum() * 1
    )
    row_stats[f'p_home_points_last_{npm}'] = points_home
    
    # Calculate points for the away team in the past `npm` games
    points_away = (
        (past_matches_away.loc[past_matches_away['HomeTeam'] == team_a, 'FTR'] == 'H').sum() * 3 +
        (past_matches_away.loc[past_matches_away['AwayTeam'] == team_a, 'FTR'] == 'A').sum() * 3 +
        (past_matches_away['FTR'] == 'D').sum() * 1
    )
    row_stats[f'p_away_points_last_{npm}'] = points_away
    
    # Append the dictionary for this row to the list
    rows_list.append(row_stats)

# Convert the list of dictionaries to a DataFrame
buli_df = pd.DataFrame(rows_list)

# Filter out the first `npm` games of each season from the final output
buli_df_first_games_skipped = buli_df.groupby('Season').apply(lambda x: x.iloc[npm:]).reset_index(drop=True)

# Display the final DataFrame with selected columns and past 7 games stats
buli_df_first_games_skipped
# Out:
# /var/folders/gk/c2gpqh3x7z74jf883m6p8r3c0000gn/T/ipykernel_75926/2652113862.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'] = pd.to_datetime(df['Date'])
# /var/folders/gk/c2gpqh3x7z74jf883m6p8r3c0000gn/T/ipykernel_75926/2652113862.py:104: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   buli_df_first_games_skipped = buli_df.groupby('Season').apply(lambda x: x.iloc[npm:]).reset_index(drop=True)
#            Date       HomeTeam       AwayTeam FTR  FTHG  FTAG  Season  \
# 0    2006-08-13      Wolfsburg         Hertha   D     0     0       1
# 1    2006-08-13       Hannover  Werder Bremen   A     2     4       1
# 2    2006-08-18       Nurnberg     M'gladbach   H     1     0       1
# 3    2006-08-19         Hertha       Hannover   H     4     0       1
# 4    2006-08-19         Aachen     Schalke 04   A     0     1       1
# ...         ...            ...            ...  ..   ...   ...     ...
# 5428 2024-10-26  Werder Bremen     Leverkusen   D     2     2      21
# 5429 2024-10-26     RB Leipzig       Freiburg   H     3     1      21
# 5430 2024-10-27   Union Berlin  Ein Frankfurt   D     1     1      21
# 5431 2024-10-27     Heidenheim     Hoffenheim   D     0     0      21
# 5432 2024-10-27         Bochum  Bayern Munich   A     0     5      21
#
#       p_home_goals_scored_last_7  p_home_goals_conceded_last_7  \
# 0                              0                             0
# 1                              0                             0
# 2                              3                             0
# 3                              0                             0
# 4                              0                             3
# ...                          ...                           ...
# 5428                          12                            14
# 5429                          11                             2
# 5430                           8                             4
# 5431                          12                            11
# 5432                           7                            17
#
#       p_home_shots_taken_last_7  ...  p_away_fouls_fouls_last_7  \
# 0                             0  ...                          0
# 1                             0  ...                          0
# 2                            11  ...                         11
# 3                            10  ...                         18
# 4                             8  ...                         17
# ...                         ...  ...                        ...
# 5428                         72  ...                         59
# 5429                         85  ...                         58
# 5430                         84  ...                         69
# 5431                         89  ...                         74
# 5432                         93  ...                         71
#
#       p_away_fouls_fouled_last_7  p_away_corners_taken_last_7  \
# 0                              0                            0
# 1                              0                            0
# 2                             24                            3
# 3                             14                            2
# 4                             19                            7
# ...                          ...                          ...
# 5428                          67                           61
# 5429                          77                           38
# 5430                          62                           32
# 5431                          92                           32
# 5432                          76                           47
#
#       p_away_corners_conceded_last_7  p_away_yellow_cards_received_last_7  \
# 0                                  0                                    0
# 1                                  0                                    0
# 2                                  5                                    0
# 3                                 11                                    1
# 4                                  5                                    1
# ...                              ...                                  ...
# 5428                              22                                   16
# 5429                              27                                    9
# 5430                              44                                    9
# 5431                              42                                   18
# 5432                              12                                   10
#
#       p_away_yellow_cards_provoked_last_7  p_away_red_cards_received_last_7  \
# 0                                       0                                 0
# 1                                       0                                 0
# 2                                       4                                 0
# 3                                       3                                 0
# 4                                       2                                 0
# ...                                   ...                               ...
# 5428                                   13                                 0
# 5429                                   11                                 0
# 5430                                    9                                 0
# 5431                                   13                                 1
# 5432                                    8                                 0
#
#       p_away_red_cards_provoked_last_7  p_home_points_last_7  \
# 0                                    0                     0
# 1                                    0                     0
# 2                                    1                     3
# 3                                    0                     1
# 4                                    0                     0
# ...                                ...                   ...
# 5428                                 1                    11
# 5429                                 0                    17
# 5430                                 0                    14
# 5431                                 1                     9
# 5432                                 0                     1
#
#       p_away_points_last_7
# 0                        0
# 1                        0
# 2                        3
# 3                        0
# 4                        1
# ...                    ...
# 5428                    14
# 5429                    15
# 5430                    13
# 5431                     7
# 5432                    17
#
# [5433 rows x 37 columns]

# %%
#seasons dont fit yet, 2 month definition not really working at some points apparently

# %% [markdown]
# ### Correlation Tests

# %%
correlation_matrix = rolling_stats.select_dtypes("number").corr()

filtered_correlation = correlation_matrix.applymap(lambda x: x if abs(x) > 0.25 else None)
filtered_correlation
# Out:
# /var/folders/gk/c2gpqh3x7z74jf883m6p8r3c0000gn/T/ipykernel_75926/1913478781.py:3: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   filtered_correlation = correlation_matrix.applymap(lambda x: x if abs(x) > 0.25 else None)
#                                         FTHG  FTAG  \
# FTHG                                     1.0   NaN
# FTAG                                     NaN   1.0
# p_home_goals_scored_last_7               NaN   NaN
# p_home_goals_conceded_last_7             NaN   NaN
# p_home_shots_taken_last_7                NaN   NaN
# p_home_shots_conceded_last_7             NaN   NaN
# p_home_shots_on_target_taken_last_7      NaN   NaN
# p_home_shots_on_target_conceded_last_7   NaN   NaN
# p_home_fouls_fouls_last_7                NaN   NaN
# p_home_fouls_fouled_last_7               NaN   NaN
# p_home_corners_taken_last_7              NaN   NaN
# p_home_corners_conceded_last_7           NaN   NaN
# p_home_yellow_cards_received_last_7      NaN   NaN
# p_home_yellow_cards_provoked_last_7      NaN   NaN
# p_home_red_cards_received_last_7         NaN   NaN
# p_home_red_cards_provoked_last_7         NaN   NaN
# p_away_goals_scored_last_7               NaN   NaN
# p_away_goals_conceded_last_7             NaN   NaN
# p_away_shots_taken_last_7                NaN   NaN
# p_away_shots_conceded_last_7             NaN   NaN
# p_away_shots_on_target_taken_last_7      NaN   NaN
# p_away_shots_on_target_conceded_last_7   NaN   NaN
# p_away_fouls_fouls_last_7                NaN   NaN
# p_away_fouls_fouled_last_7               NaN   NaN
# p_away_corners_taken_last_7              NaN   NaN
# p_away_corners_conceded_last_7           NaN   NaN
# p_away_yellow_cards_received_last_7      NaN   NaN
# p_away_yellow_cards_provoked_last_7      NaN   NaN
# p_away_red_cards_received_last_7         NaN   NaN
# p_away_red_cards_provoked_last_7         NaN   NaN
# p_home_points_last_7                     NaN   NaN
# p_away_points_last_7                     NaN   NaN
#
#                                         p_home_goals_scored_last_7  \
# FTHG                                                           NaN
# FTAG                                                           NaN
# p_home_goals_scored_last_7                                1.000000
# p_home_goals_conceded_last_7                                   NaN
# p_home_shots_taken_last_7                                 0.565705
# p_home_shots_conceded_last_7                                   NaN
# p_home_shots_on_target_taken_last_7                       0.653538
# p_home_shots_on_target_conceded_last_7                         NaN
# p_home_fouls_fouls_last_7                                      NaN
# p_home_fouls_fouled_last_7                                     NaN
# p_home_corners_taken_last_7                               0.367425
# p_home_corners_conceded_last_7                                 NaN
# p_home_yellow_cards_received_last_7                            NaN
# p_home_yellow_cards_provoked_last_7                            NaN
# p_home_red_cards_received_last_7                               NaN
# p_home_red_cards_provoked_last_7                               NaN
# p_away_goals_scored_last_7                                     NaN
# p_away_goals_conceded_last_7                                   NaN
# p_away_shots_taken_last_7                                      NaN
# p_away_shots_conceded_last_7                                   NaN
# p_away_shots_on_target_taken_last_7                            NaN
# p_away_shots_on_target_conceded_last_7                         NaN
# p_away_fouls_fouls_last_7                                      NaN
# p_away_fouls_fouled_last_7                                     NaN
# p_away_corners_taken_last_7                                    NaN
# p_away_corners_conceded_last_7                                 NaN
# p_away_yellow_cards_received_last_7                            NaN
# p_away_yellow_cards_provoked_last_7                            NaN
# p_away_red_cards_received_last_7                               NaN
# p_away_red_cards_provoked_last_7                               NaN
# p_home_points_last_7                                      0.778772
# p_away_points_last_7                                           NaN
#
#                                         p_home_goals_conceded_last_7  \
# FTHG                                                             NaN
# FTAG                                                             NaN
# p_home_goals_scored_last_7                                       NaN
# p_home_goals_conceded_last_7                                1.000000
# p_home_shots_taken_last_7                                        NaN
# p_home_shots_conceded_last_7                                0.501412
# p_home_shots_on_target_taken_last_7                              NaN
# p_home_shots_on_target_conceded_last_7                      0.564792
# p_home_fouls_fouls_last_7                                        NaN
# p_home_fouls_fouled_last_7                                       NaN
# p_home_corners_taken_last_7                                      NaN
# p_home_corners_conceded_last_7                              0.309935
# p_home_yellow_cards_received_last_7                         0.274800
# p_home_yellow_cards_provoked_last_7                              NaN
# p_home_red_cards_received_last_7                                 NaN
# p_home_red_cards_provoked_last_7                                 NaN
# p_away_goals_scored_last_7                                       NaN
# p_away_goals_conceded_last_7                                     NaN
# p_away_shots_taken_last_7                                        NaN
# p_away_shots_conceded_last_7                                     NaN
# p_away_shots_on_target_taken_last_7                              NaN
# p_away_shots_on_target_conceded_last_7                           NaN
# p_away_fouls_fouls_last_7                                        NaN
# p_away_fouls_fouled_last_7                                       NaN
# p_away_corners_taken_last_7                                      NaN
# p_away_corners_conceded_last_7                                   NaN
# p_away_yellow_cards_received_last_7                              NaN
# p_away_yellow_cards_provoked_last_7                              NaN
# p_away_red_cards_received_last_7                                 NaN
# p_away_red_cards_provoked_last_7                                 NaN
# p_home_points_last_7                                       -0.577746
# p_away_points_last_7                                             NaN
#
#                                         p_home_shots_taken_last_7  \
# FTHG                                                          NaN
# FTAG                                                          NaN
# p_home_goals_scored_last_7                               0.565705
# p_home_goals_conceded_last_7                                  NaN
# p_home_shots_taken_last_7                                1.000000
# p_home_shots_conceded_last_7                                  NaN
# p_home_shots_on_target_taken_last_7                      0.775212
# p_home_shots_on_target_conceded_last_7                        NaN
# p_home_fouls_fouls_last_7                                     NaN
# p_home_fouls_fouled_last_7                                    NaN
# p_home_corners_taken_last_7                              0.687314
# p_home_corners_conceded_last_7                                NaN
# p_home_yellow_cards_received_last_7                           NaN
# p_home_yellow_cards_provoked_last_7                           NaN
# p_home_red_cards_received_last_7                              NaN
# p_home_red_cards_provoked_last_7                              NaN
# p_away_goals_scored_last_7                                    NaN
# p_away_goals_conceded_last_7                                  NaN
# p_away_shots_taken_last_7                                     NaN
# p_away_shots_conceded_last_7                                  NaN
# p_away_shots_on_target_taken_last_7                           NaN
# p_away_shots_on_target_conceded_last_7                        NaN
# p_away_fouls_fouls_last_7                                     NaN
# p_away_fouls_fouled_last_7                                    NaN
# p_away_corners_taken_last_7                                   NaN
# p_away_corners_conceded_last_7                                NaN
# p_away_yellow_cards_received_last_7                           NaN
# p_away_yellow_cards_provoked_last_7                           NaN
# p_away_red_cards_received_last_7                              NaN
# p_away_red_cards_provoked_last_7                              NaN
# p_home_points_last_7                                     0.481141
# p_away_points_last_7                                          NaN
#
#                                         p_home_shots_conceded_last_7  \
# FTHG                                                             NaN
# FTAG                                                             NaN
# p_home_goals_scored_last_7                                       NaN
# p_home_goals_conceded_last_7                                0.501412
# p_home_shots_taken_last_7                                        NaN
# p_home_shots_conceded_last_7                                1.000000
# p_home_shots_on_target_taken_last_7                              NaN
# p_home_shots_on_target_conceded_last_7                      0.740387
# p_home_fouls_fouls_last_7                                   0.273140
# p_home_fouls_fouled_last_7                                       NaN
# p_home_corners_taken_last_7                                      NaN
# p_home_corners_conceded_last_7                              0.693046
# p_home_yellow_cards_received_last_7                         0.294746
# p_home_yellow_cards_provoked_last_7                              NaN
# p_home_red_cards_received_last_7                                 NaN
# p_home_red_cards_provoked_last_7                                 NaN
# p_away_goals_scored_last_7                                       NaN
# p_away_goals_conceded_last_7                                     NaN
# p_away_shots_taken_last_7                                        NaN
# p_away_shots_conceded_last_7                                     NaN
# p_away_shots_on_target_taken_last_7                              NaN
# p_away_shots_on_target_conceded_last_7                           NaN
# p_away_fouls_fouls_last_7                                        NaN
# p_away_fouls_fouled_last_7                                       NaN
# p_away_corners_taken_last_7                                      NaN
# p_away_corners_conceded_last_7                                   NaN
# p_away_yellow_cards_received_last_7                              NaN
# p_away_yellow_cards_provoked_last_7                              NaN
# p_away_red_cards_received_last_7                                 NaN
# p_away_red_cards_provoked_last_7                                 NaN
# p_home_points_last_7                                       -0.298402
# p_away_points_last_7                                             NaN
#
#                                         p_home_shots_on_target_taken_last_7  \
# FTHG                                                                    NaN
# FTAG                                                                    NaN
# p_home_goals_scored_last_7                                         0.653538
# p_home_goals_conceded_last_7                                            NaN
# p_home_shots_taken_last_7                                          0.775212
# p_home_shots_conceded_last_7                                            NaN
# p_home_shots_on_target_taken_last_7                                1.000000
# p_home_shots_on_target_conceded_last_7                                  NaN
# p_home_fouls_fouls_last_7                                               NaN
# p_home_fouls_fouled_last_7                                              NaN
# p_home_corners_taken_last_7                                        0.528987
# p_home_corners_conceded_last_7                                          NaN
# p_home_yellow_cards_received_last_7                                     NaN
# p_home_yellow_cards_provoked_last_7                                     NaN
# p_home_red_cards_received_last_7                                        NaN
# p_home_red_cards_provoked_last_7                                        NaN
# p_away_goals_scored_last_7                                              NaN
# p_away_goals_conceded_last_7                                            NaN
# p_away_shots_taken_last_7                                               NaN
# p_away_shots_conceded_last_7                                            NaN
# p_away_shots_on_target_taken_last_7                                     NaN
# p_away_shots_on_target_conceded_last_7                                  NaN
# p_away_fouls_fouls_last_7                                               NaN
# p_away_fouls_fouled_last_7                                              NaN
# p_away_corners_taken_last_7                                             NaN
# p_away_corners_conceded_last_7                                          NaN
# p_away_yellow_cards_received_last_7                                     NaN
# p_away_yellow_cards_provoked_last_7                                     NaN
# p_away_red_cards_received_last_7                                        NaN
# p_away_red_cards_provoked_last_7                                        NaN
# p_home_points_last_7                                               0.555587
# p_away_points_last_7                                                    NaN
#
#                                         p_home_shots_on_target_conceded_last_7  \
# FTHG                                                                       NaN
# FTAG                                                                       NaN
# p_home_goals_scored_last_7                                                 NaN
# p_home_goals_conceded_last_7                                          0.564792
# p_home_shots_taken_last_7                                                  NaN
# p_home_shots_conceded_last_7                                          0.740387
# p_home_shots_on_target_taken_last_7                                        NaN
# p_home_shots_on_target_conceded_last_7                                1.000000
# p_home_fouls_fouls_last_7                                             0.292585
# p_home_fouls_fouled_last_7                                                 NaN
# p_home_corners_taken_last_7                                                NaN
# p_home_corners_conceded_last_7                                        0.494918
# p_home_yellow_cards_received_last_7                                   0.255088
# p_home_yellow_cards_provoked_last_7                                        NaN
# p_home_red_cards_received_last_7                                           NaN
# p_home_red_cards_provoked_last_7                                           NaN
# p_away_goals_scored_last_7                                                 NaN
# p_away_goals_conceded_last_7                                               NaN
# p_away_shots_taken_last_7                                                  NaN
# p_away_shots_conceded_last_7                                               NaN
# p_away_shots_on_target_taken_last_7                                        NaN
# p_away_shots_on_target_conceded_last_7                                     NaN
# p_away_fouls_fouls_last_7                                                  NaN
# p_away_fouls_fouled_last_7                                                 NaN
# p_away_corners_taken_last_7                                                NaN
# p_away_corners_conceded_last_7                                             NaN
# p_away_yellow_cards_received_last_7                                        NaN
# p_away_yellow_cards_provoked_last_7                                        NaN
# p_away_red_cards_received_last_7                                           NaN
# p_away_red_cards_provoked_last_7                                           NaN
# p_home_points_last_7                                                 -0.368976
# p_away_points_last_7                                                       NaN
#
#                                         p_home_fouls_fouls_last_7  \
# FTHG                                                          NaN
# FTAG                                                          NaN
# p_home_goals_scored_last_7                                    NaN
# p_home_goals_conceded_last_7                                  NaN
# p_home_shots_taken_last_7                                     NaN
# p_home_shots_conceded_last_7                             0.273140
# p_home_shots_on_target_taken_last_7                           NaN
# p_home_shots_on_target_conceded_last_7                   0.292585
# p_home_fouls_fouls_last_7                                1.000000
# p_home_fouls_fouled_last_7                               0.710276
# p_home_corners_taken_last_7                                   NaN
# p_home_corners_conceded_last_7                                NaN
# p_home_yellow_cards_received_last_7                      0.317228
# p_home_yellow_cards_provoked_last_7                           NaN
# p_home_red_cards_received_last_7                              NaN
# p_home_red_cards_provoked_last_7                              NaN
# p_away_goals_scored_last_7                                    NaN
# p_away_goals_conceded_last_7                                  NaN
# p_away_shots_taken_last_7                                     NaN
# p_away_shots_conceded_last_7                                  NaN
# p_away_shots_on_target_taken_last_7                           NaN
# p_away_shots_on_target_conceded_last_7                        NaN
# p_away_fouls_fouls_last_7                                0.534836
# p_away_fouls_fouled_last_7                               0.547929
# p_away_corners_taken_last_7                                   NaN
# p_away_corners_conceded_last_7                                NaN
# p_away_yellow_cards_received_last_7                           NaN
# p_away_yellow_cards_provoked_last_7                           NaN
# p_away_red_cards_received_last_7                              NaN
# p_away_red_cards_provoked_last_7                              NaN
# p_home_points_last_7                                          NaN
# p_away_points_last_7                                          NaN
#
#                                         p_home_fouls_fouled_last_7  ...  \
# FTHG                                                           NaN  ...
# FTAG                                                           NaN  ...
# p_home_goals_scored_last_7                                     NaN  ...
# p_home_goals_conceded_last_7                                   NaN  ...
# p_home_shots_taken_last_7                                      NaN  ...
# p_home_shots_conceded_last_7                                   NaN  ...
# p_home_shots_on_target_taken_last_7                            NaN  ...
# p_home_shots_on_target_conceded_last_7                         NaN  ...
# p_home_fouls_fouls_last_7                                 0.710276  ...
# p_home_fouls_fouled_last_7                                1.000000  ...
# p_home_corners_taken_last_7                                    NaN  ...
# p_home_corners_conceded_last_7                                 NaN  ...
# p_home_yellow_cards_received_last_7                            NaN  ...
# p_home_yellow_cards_provoked_last_7                       0.286265  ...
# p_home_red_cards_received_last_7                               NaN  ...
# p_home_red_cards_provoked_last_7                               NaN  ...
# p_away_goals_scored_last_7                                     NaN  ...
# p_away_goals_conceded_last_7                                   NaN  ...
# p_away_shots_taken_last_7                                      NaN  ...
# p_away_shots_conceded_last_7                                   NaN  ...
# p_away_shots_on_target_taken_last_7                            NaN  ...
# p_away_shots_on_target_conceded_last_7                         NaN  ...
# p_away_fouls_fouls_last_7                                 0.547990  ...
# p_away_fouls_fouled_last_7                                0.574253  ...
# p_away_corners_taken_last_7                                    NaN  ...
# p_away_corners_conceded_last_7                                 NaN  ...
# p_away_yellow_cards_received_last_7                            NaN  ...
# p_away_yellow_cards_provoked_last_7                            NaN  ...
# p_away_red_cards_received_last_7                               NaN  ...
# p_away_red_cards_provoked_last_7                               NaN  ...
# p_home_points_last_7                                           NaN  ...
# p_away_points_last_7                                           NaN  ...
#
#                                         p_away_fouls_fouls_last_7  \
# FTHG                                                          NaN
# FTAG                                                          NaN
# p_home_goals_scored_last_7                                    NaN
# p_home_goals_conceded_last_7                                  NaN
# p_home_shots_taken_last_7                                     NaN
# p_home_shots_conceded_last_7                                  NaN
# p_home_shots_on_target_taken_last_7                           NaN
# p_home_shots_on_target_conceded_last_7                        NaN
# p_home_fouls_fouls_last_7                                0.534836
# p_home_fouls_fouled_last_7                               0.547990
# p_home_corners_taken_last_7                                   NaN
# p_home_corners_conceded_last_7                                NaN
# p_home_yellow_cards_received_last_7                           NaN
# p_home_yellow_cards_provoked_last_7                           NaN
# p_home_red_cards_received_last_7                              NaN
# p_home_red_cards_provoked_last_7                              NaN
# p_away_goals_scored_last_7                                    NaN
# p_away_goals_conceded_last_7                                  NaN
# p_away_shots_taken_last_7                                     NaN
# p_away_shots_conceded_last_7                             0.273376
# p_away_shots_on_target_taken_last_7                           NaN
# p_away_shots_on_target_conceded_last_7                   0.297161
# p_away_fouls_fouls_last_7                                1.000000
# p_away_fouls_fouled_last_7                               0.711485
# p_away_corners_taken_last_7                                   NaN
# p_away_corners_conceded_last_7                                NaN
# p_away_yellow_cards_received_last_7                      0.323611
# p_away_yellow_cards_provoked_last_7                           NaN
# p_away_red_cards_received_last_7                              NaN
# p_away_red_cards_provoked_last_7                              NaN
# p_home_points_last_7                                          NaN
# p_away_points_last_7                                          NaN
#
#                                         p_away_fouls_fouled_last_7  \
# FTHG                                                           NaN
# FTAG                                                           NaN
# p_home_goals_scored_last_7                                     NaN
# p_home_goals_conceded_last_7                                   NaN
# p_home_shots_taken_last_7                                      NaN
# p_home_shots_conceded_last_7                                   NaN
# p_home_shots_on_target_taken_last_7                            NaN
# p_home_shots_on_target_conceded_last_7                         NaN
# p_home_fouls_fouls_last_7                                 0.547929
# p_home_fouls_fouled_last_7                                0.574253
# p_home_corners_taken_last_7                                    NaN
# p_home_corners_conceded_last_7                                 NaN
# p_home_yellow_cards_received_last_7                            NaN
# p_home_yellow_cards_provoked_last_7                            NaN
# p_home_red_cards_received_last_7                               NaN
# p_home_red_cards_provoked_last_7                               NaN
# p_away_goals_scored_last_7                                     NaN
# p_away_goals_conceded_last_7                                   NaN
# p_away_shots_taken_last_7                                      NaN
# p_away_shots_conceded_last_7                                   NaN
# p_away_shots_on_target_taken_last_7                            NaN
# p_away_shots_on_target_conceded_last_7                         NaN
# p_away_fouls_fouls_last_7                                 0.711485
# p_away_fouls_fouled_last_7                                1.000000
# p_away_corners_taken_last_7                                    NaN
# p_away_corners_conceded_last_7                                 NaN
# p_away_yellow_cards_received_last_7                            NaN
# p_away_yellow_cards_provoked_last_7                       0.289583
# p_away_red_cards_received_last_7                               NaN
# p_away_red_cards_provoked_last_7                               NaN
# p_home_points_last_7                                           NaN
# p_away_points_last_7                                           NaN
#
#                                         p_away_corners_taken_last_7  \
# FTHG                                                            NaN
# FTAG                                                            NaN
# p_home_goals_scored_last_7                                      NaN
# p_home_goals_conceded_last_7                                    NaN
# p_home_shots_taken_last_7                                       NaN
# p_home_shots_conceded_last_7                                    NaN
# p_home_shots_on_target_taken_last_7                             NaN
# p_home_shots_on_target_conceded_last_7                          NaN
# p_home_fouls_fouls_last_7                                       NaN
# p_home_fouls_fouled_last_7                                      NaN
# p_home_corners_taken_last_7                                     NaN
# p_home_corners_conceded_last_7                                  NaN
# p_home_yellow_cards_received_last_7                             NaN
# p_home_yellow_cards_provoked_last_7                             NaN
# p_home_red_cards_received_last_7                                NaN
# p_home_red_cards_provoked_last_7                                NaN
# p_away_goals_scored_last_7                                 0.372442
# p_away_goals_conceded_last_7                                    NaN
# p_away_shots_taken_last_7                                  0.685500
# p_away_shots_conceded_last_7                                    NaN
# p_away_shots_on_target_taken_last_7                        0.526889
# p_away_shots_on_target_conceded_last_7                          NaN
# p_away_fouls_fouls_last_7                                       NaN
# p_away_fouls_fouled_last_7                                      NaN
# p_away_corners_taken_last_7                                1.000000
# p_away_corners_conceded_last_7                                  NaN
# p_away_yellow_cards_received_last_7                             NaN
# p_away_yellow_cards_provoked_last_7                             NaN
# p_away_red_cards_received_last_7                                NaN
# p_away_red_cards_provoked_last_7                                NaN
# p_home_points_last_7                                            NaN
# p_away_points_last_7                                       0.315881
#
#                                         p_away_corners_conceded_last_7  \
# FTHG                                                               NaN
# FTAG                                                               NaN
# p_home_goals_scored_last_7                                         NaN
# p_home_goals_conceded_last_7                                       NaN
# p_home_shots_taken_last_7                                          NaN
# p_home_shots_conceded_last_7                                       NaN
# p_home_shots_on_target_taken_last_7                                NaN
# p_home_shots_on_target_conceded_last_7                             NaN
# p_home_fouls_fouls_last_7                                          NaN
# p_home_fouls_fouled_last_7                                         NaN
# p_home_corners_taken_last_7                                        NaN
# p_home_corners_conceded_last_7                                     NaN
# p_home_yellow_cards_received_last_7                                NaN
# p_home_yellow_cards_provoked_last_7                                NaN
# p_home_red_cards_received_last_7                                   NaN
# p_home_red_cards_provoked_last_7                                   NaN
# p_away_goals_scored_last_7                                         NaN
# p_away_goals_conceded_last_7                                  0.314750
# p_away_shots_taken_last_7                                          NaN
# p_away_shots_conceded_last_7                                  0.695684
# p_away_shots_on_target_taken_last_7                                NaN
# p_away_shots_on_target_conceded_last_7                        0.498340
# p_away_fouls_fouls_last_7                                          NaN
# p_away_fouls_fouled_last_7                                         NaN
# p_away_corners_taken_last_7                                        NaN
# p_away_corners_conceded_last_7                                1.000000
# p_away_yellow_cards_received_last_7                                NaN
# p_away_yellow_cards_provoked_last_7                                NaN
# p_away_red_cards_received_last_7                                   NaN
# p_away_red_cards_provoked_last_7                                   NaN
# p_home_points_last_7                                               NaN
# p_away_points_last_7                                               NaN
#
#                                         p_away_yellow_cards_received_last_7  \
# FTHG                                                                    NaN
# FTAG                                                                    NaN
# p_home_goals_scored_last_7                                              NaN
# p_home_goals_conceded_last_7                                            NaN
# p_home_shots_taken_last_7                                               NaN
# p_home_shots_conceded_last_7                                            NaN
# p_home_shots_on_target_taken_last_7                                     NaN
# p_home_shots_on_target_conceded_last_7                                  NaN
# p_home_fouls_fouls_last_7                                               NaN
# p_home_fouls_fouled_last_7                                              NaN
# p_home_corners_taken_last_7                                             NaN
# p_home_corners_conceded_last_7                                          NaN
# p_home_yellow_cards_received_last_7                                     NaN
# p_home_yellow_cards_provoked_last_7                                     NaN
# p_home_red_cards_received_last_7                                        NaN
# p_home_red_cards_provoked_last_7                                        NaN
# p_away_goals_scored_last_7                                              NaN
# p_away_goals_conceded_last_7                                       0.283303
# p_away_shots_taken_last_7                                               NaN
# p_away_shots_conceded_last_7                                       0.299706
# p_away_shots_on_target_taken_last_7                                     NaN
# p_away_shots_on_target_conceded_last_7                             0.261623
# p_away_fouls_fouls_last_7                                          0.323611
# p_away_fouls_fouled_last_7                                              NaN
# p_away_corners_taken_last_7                                             NaN
# p_away_corners_conceded_last_7                                          NaN
# p_away_yellow_cards_received_last_7                                1.000000
# p_away_yellow_cards_provoked_last_7                                0.274723
# p_away_red_cards_received_last_7                                        NaN
# p_away_red_cards_provoked_last_7                                        NaN
# p_home_points_last_7                                                    NaN
# p_away_points_last_7                                                    NaN
#
#                                         p_away_yellow_cards_provoked_last_7  \
# FTHG                                                                    NaN
# FTAG                                                                    NaN
# p_home_goals_scored_last_7                                              NaN
# p_home_goals_conceded_last_7                                            NaN
# p_home_shots_taken_last_7                                               NaN
# p_home_shots_conceded_last_7                                            NaN
# p_home_shots_on_target_taken_last_7                                     NaN
# p_home_shots_on_target_conceded_last_7                                  NaN
# p_home_fouls_fouls_last_7                                               NaN
# p_home_fouls_fouled_last_7                                              NaN
# p_home_corners_taken_last_7                                             NaN
# p_home_corners_conceded_last_7                                          NaN
# p_home_yellow_cards_received_last_7                                     NaN
# p_home_yellow_cards_provoked_last_7                                     NaN
# p_home_red_cards_received_last_7                                        NaN
# p_home_red_cards_provoked_last_7                                        NaN
# p_away_goals_scored_last_7                                              NaN
# p_away_goals_conceded_last_7                                            NaN
# p_away_shots_taken_last_7                                               NaN
# p_away_shots_conceded_last_7                                            NaN
# p_away_shots_on_target_taken_last_7                                     NaN
# p_away_shots_on_target_conceded_last_7                                  NaN
# p_away_fouls_fouls_last_7                                               NaN
# p_away_fouls_fouled_last_7                                         0.289583
# p_away_corners_taken_last_7                                             NaN
# p_away_corners_conceded_last_7                                          NaN
# p_away_yellow_cards_received_last_7                                0.274723
# p_away_yellow_cards_provoked_last_7                                1.000000
# p_away_red_cards_received_last_7                                        NaN
# p_away_red_cards_provoked_last_7                                        NaN
# p_home_points_last_7                                                    NaN
# p_away_points_last_7                                                    NaN
#
#                                         p_away_red_cards_received_last_7  \
# FTHG                                                                 NaN
# FTAG                                                                 NaN
# p_home_goals_scored_last_7                                           NaN
# p_home_goals_conceded_last_7                                         NaN
# p_home_shots_taken_last_7                                            NaN
# p_home_shots_conceded_last_7                                         NaN
# p_home_shots_on_target_taken_last_7                                  NaN
# p_home_shots_on_target_conceded_last_7                               NaN
# p_home_fouls_fouls_last_7                                            NaN
# p_home_fouls_fouled_last_7                                           NaN
# p_home_corners_taken_last_7                                          NaN
# p_home_corners_conceded_last_7                                       NaN
# p_home_yellow_cards_received_last_7                                  NaN
# p_home_yellow_cards_provoked_last_7                                  NaN
# p_home_red_cards_received_last_7                                     NaN
# p_home_red_cards_provoked_last_7                                     NaN
# p_away_goals_scored_last_7                                           NaN
# p_away_goals_conceded_last_7                                         NaN
# p_away_shots_taken_last_7                                            NaN
# p_away_shots_conceded_last_7                                         NaN
# p_away_shots_on_target_taken_last_7                                  NaN
# p_away_shots_on_target_conceded_last_7                               NaN
# p_away_fouls_fouls_last_7                                            NaN
# p_away_fouls_fouled_last_7                                           NaN
# p_away_corners_taken_last_7                                          NaN
# p_away_corners_conceded_last_7                                       NaN
# p_away_yellow_cards_received_last_7                                  NaN
# p_away_yellow_cards_provoked_last_7                                  NaN
# p_away_red_cards_received_last_7                                     1.0
# p_away_red_cards_provoked_last_7                                     NaN
# p_home_points_last_7                                                 NaN
# p_away_points_last_7                                                 NaN
#
#                                         p_away_red_cards_provoked_last_7  \
# FTHG                                                                 NaN
# FTAG                                                                 NaN
# p_home_goals_scored_last_7                                           NaN
# p_home_goals_conceded_last_7                                         NaN
# p_home_shots_taken_last_7                                            NaN
# p_home_shots_conceded_last_7                                         NaN
# p_home_shots_on_target_taken_last_7                                  NaN
# p_home_shots_on_target_conceded_last_7                               NaN
# p_home_fouls_fouls_last_7                                            NaN
# p_home_fouls_fouled_last_7                                           NaN
# p_home_corners_taken_last_7                                          NaN
# p_home_corners_conceded_last_7                                       NaN
# p_home_yellow_cards_received_last_7                                  NaN
# p_home_yellow_cards_provoked_last_7                                  NaN
# p_home_red_cards_received_last_7                                     NaN
# p_home_red_cards_provoked_last_7                                     NaN
# p_away_goals_scored_last_7                                           NaN
# p_away_goals_conceded_last_7                                         NaN
# p_away_shots_taken_last_7                                            NaN
# p_away_shots_conceded_last_7                                         NaN
# p_away_shots_on_target_taken_last_7                                  NaN
# p_away_shots_on_target_conceded_last_7                               NaN
# p_away_fouls_fouls_last_7                                            NaN
# p_away_fouls_fouled_last_7                                           NaN
# p_away_corners_taken_last_7                                          NaN
# p_away_corners_conceded_last_7                                       NaN
# p_away_yellow_cards_received_last_7                                  NaN
# p_away_yellow_cards_provoked_last_7                                  NaN
# p_away_red_cards_received_last_7                                     NaN
# p_away_red_cards_provoked_last_7                                     1.0
# p_home_points_last_7                                                 NaN
# p_away_points_last_7                                                 NaN
#
#                                         p_home_points_last_7  \
# FTHG                                                     NaN
# FTAG                                                     NaN
# p_home_goals_scored_last_7                          0.778772
# p_home_goals_conceded_last_7                       -0.577746
# p_home_shots_taken_last_7                           0.481141
# p_home_shots_conceded_last_7                       -0.298402
# p_home_shots_on_target_taken_last_7                 0.555587
# p_home_shots_on_target_conceded_last_7             -0.368976
# p_home_fouls_fouls_last_7                                NaN
# p_home_fouls_fouled_last_7                               NaN
# p_home_corners_taken_last_7                         0.316773
# p_home_corners_conceded_last_7                           NaN
# p_home_yellow_cards_received_last_7                      NaN
# p_home_yellow_cards_provoked_last_7                      NaN
# p_home_red_cards_received_last_7                         NaN
# p_home_red_cards_provoked_last_7                         NaN
# p_away_goals_scored_last_7                               NaN
# p_away_goals_conceded_last_7                             NaN
# p_away_shots_taken_last_7                                NaN
# p_away_shots_conceded_last_7                             NaN
# p_away_shots_on_target_taken_last_7                      NaN
# p_away_shots_on_target_conceded_last_7                   NaN
# p_away_fouls_fouls_last_7                                NaN
# p_away_fouls_fouled_last_7                               NaN
# p_away_corners_taken_last_7                              NaN
# p_away_corners_conceded_last_7                           NaN
# p_away_yellow_cards_received_last_7                      NaN
# p_away_yellow_cards_provoked_last_7                      NaN
# p_away_red_cards_received_last_7                         NaN
# p_away_red_cards_provoked_last_7                         NaN
# p_home_points_last_7                                1.000000
# p_away_points_last_7                                     NaN
#
#                                         p_away_points_last_7
# FTHG                                                     NaN
# FTAG                                                     NaN
# p_home_goals_scored_last_7                               NaN
# p_home_goals_conceded_last_7                             NaN
# p_home_shots_taken_last_7                                NaN
# p_home_shots_conceded_last_7                             NaN
# p_home_shots_on_target_taken_last_7                      NaN
# p_home_shots_on_target_conceded_last_7                   NaN
# p_home_fouls_fouls_last_7                                NaN
# p_home_fouls_fouled_last_7                               NaN
# p_home_corners_taken_last_7                              NaN
# p_home_corners_conceded_last_7                           NaN
# p_home_yellow_cards_received_last_7                      NaN
# p_home_yellow_cards_provoked_last_7                      NaN
# p_home_red_cards_received_last_7                         NaN
# p_home_red_cards_provoked_last_7                         NaN
# p_away_goals_scored_last_7                          0.778817
# p_away_goals_conceded_last_7                       -0.583514
# p_away_shots_taken_last_7                           0.489464
# p_away_shots_conceded_last_7                       -0.299773
# p_away_shots_on_target_taken_last_7                 0.560192
# p_away_shots_on_target_conceded_last_7             -0.367575
# p_away_fouls_fouls_last_7                                NaN
# p_away_fouls_fouled_last_7                               NaN
# p_away_corners_taken_last_7                         0.315881
# p_away_corners_conceded_last_7                           NaN
# p_away_yellow_cards_received_last_7                      NaN
# p_away_yellow_cards_provoked_last_7                      NaN
# p_away_red_cards_received_last_7                         NaN
# p_away_red_cards_provoked_last_7                         NaN
# p_home_points_last_7                                     NaN
# p_away_points_last_7                                1.000000
#
# [32 rows x 32 columns]

# %% [markdown]
# ### Engineering "FTR" feature

# %%
rolling_stats["FTR_num"] = rolling_stats["FTR"].apply(lambda x: 1 if x == "D" else (2 if x == "H" else 3))

# %% [markdown]
# ### Train / Test Split

# %%
features = rolling_stats.select_dtypes("number").drop(columns=["FTHG", "FTAG"])
target = rolling_stats["FTHG"]

X_train, X_test, y_train, y_test = train_test_split(features, target, random_state = 0)

# %% [markdown]
# ### Scaling

# %%
scaler = MinMaxScaler()
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# # Descision Tree - Regressor - Home Goals

# %%
tree = DecisionTreeRegressor(max_depth=3)
tree.fit(X_train_scaled, y_train)
# Out:
# DecisionTreeRegressor(max_depth=3)

# %%
pred = tree.predict(X_test_scaled)

print("MAE", mean_absolute_error(pred, y_test))
print("RMSE", mean_squared_error(pred, y_test, squared=False))
print("R2 score", tree.score(X_test_scaled, y_test))
# Out:
# MAE 0.7764994976122089
# RMSE 0.989011514556089
# R2 score 0.44869297807114694
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
X_train_scaled = pd.DataFrame(X_train_scaled, columns = X_train.columns)
X_train_scaled.head()
# Out:
#    p_home_goals_scored_last_7  p_home_goals_conceded_last_7  \
# 0                    0.103448                      0.703704
# 1                    0.448276                      0.407407
# 2                    0.275862                      0.555556
# 3                    0.620690                      0.407407
# 4                    0.586207                      0.333333
#
#    p_home_shots_taken_last_7  p_home_shots_conceded_last_7  \
# 0                   0.448864                      0.723926
# 1                   0.687500                      0.570552
# 2                   0.545455                      0.674847
# 3                   0.636364                      0.533742
# 4                   0.664773                      0.404908
#
#    p_home_shots_on_target_taken_last_7  \
# 0                             0.317073
# 1                             0.670732
# 2                             0.353659
# 3                             0.585366
# 4                             0.597561
#
#    p_home_shots_on_target_conceded_last_7  p_home_fouls_fouls_last_7  \
# 0                                0.559524                   0.505747
# 1                                0.452381                   0.574713
# 2                                0.571429                   0.586207
# 3                                0.309524                   0.683908
# 4                                0.297619                   0.563218
#
#    p_home_fouls_fouled_last_7  p_home_corners_taken_last_7  \
# 0                    0.511111                     0.492958
# 1                    0.444444                     0.929577
# 2                    0.388889                     0.577465
# 3                    0.650000                     0.535211
# 4                    0.555556                     0.760563
#
#    p_home_corners_conceded_last_7  ...  p_away_fouls_fouled_last_7  \
# 0                        0.800000  ...                    0.413043
# 1                        0.338462  ...                    0.500000
# 2                        0.569231  ...                    0.434783
# 3                        0.569231  ...                    0.576087
# 4                        0.430769  ...                    0.554348
#
#    p_away_corners_taken_last_7  p_away_corners_conceded_last_7  \
# 0                     0.416667                        0.603175
# 1                     0.472222                        0.809524
# 2                     0.305556                        0.603175
# 3                     0.430556                        0.888889
# 4                     0.541667                        0.380952
#
#    p_away_yellow_cards_received_last_7  p_away_yellow_cards_provoked_last_7  \
# 0                              0.40625                             0.740741
# 1                              0.31250                             0.481481
# 2                              0.37500                             0.296296
# 3                              0.31250                             0.222222
# 4                              0.31250                             0.296296
#
#    p_away_red_cards_received_last_7  p_away_red_cards_provoked_last_7  \
# 0                              0.25                              0.25
# 1                              0.50                              0.00
# 2                              0.50                              0.25
# 3                              0.00                              0.00
# 4                              0.00                              0.00
#
#    p_home_points_last_7  p_away_points_last_7  FTR_num
# 0              0.000000              0.619048      0.0
# 1              0.619048              0.380952      0.5
# 2              0.428571              0.285714      1.0
# 3              0.571429              0.380952      1.0
# 4              0.571429              0.666667      1.0
#
# [5 rows x 31 columns]

# %%
tree_importance = {feature : importance for feature, importance in zip(X_train_scaled.columns, tree.feature_importances_)}
tree_importance
# Out:
# {'p_home_goals_scored_last_7': 0.45718420650269476,
#  'p_home_goals_conceded_last_7': 0.0,
#  'p_home_shots_taken_last_7': 0.16927663520882538,
#  'p_home_shots_conceded_last_7': 0.0,
#  'p_home_shots_on_target_taken_last_7': 0.0,
#  'p_home_shots_on_target_conceded_last_7': 0.0,
#  'p_home_fouls_fouls_last_7': 0.12083341223941044,
#  'p_home_fouls_fouled_last_7': 0.0,
#  'p_home_corners_taken_last_7': 0.0,
#  'p_home_corners_conceded_last_7': 0.0,
#  'p_home_yellow_cards_received_last_7': 0.0,
#  'p_home_yellow_cards_provoked_last_7': 0.0,
#  'p_home_red_cards_received_last_7': 0.0,
#  'p_home_red_cards_provoked_last_7': 0.0,
#  'p_away_goals_scored_last_7': 0.04221065883506092,
#  'p_away_goals_conceded_last_7': 0.0,
#  'p_away_shots_taken_last_7': 0.0,
#  'p_away_shots_conceded_last_7': 0.14522020847840136,
#  'p_away_shots_on_target_taken_last_7': 0.0,
#  'p_away_shots_on_target_conceded_last_7': 0.0,
#  'p_away_fouls_fouls_last_7': 0.0,
#  'p_away_fouls_fouled_last_7': 0.0,
#  'p_away_corners_taken_last_7': 0.0,
#  'p_away_corners_conceded_last_7': 0.0,
#  'p_away_yellow_cards_received_last_7': 0.0,
#  'p_away_yellow_cards_provoked_last_7': 0.0,
#  'p_away_red_cards_received_last_7': 0.0,
#  'p_away_red_cards_provoked_last_7': 0.0,
#  'p_home_points_last_7': 0.0,
#  'p_away_points_last_7': 0.06527487873560721}

# %% [markdown]
# ## Updating Features

# %%
# Assuming X_train and X_test are the original DataFrames with column names
X_train_scaled = pd.DataFrame(X_train_scaled, columns=X_train.columns)
X_test_scaled = pd.DataFrame(X_test_scaled, columns=X_test.columns)

# Now you can select the specific columns for each
X_train_scaled_new = X_train_scaled[[
    "p_home_goals_scored_last_7", "p_home_shots_taken_last_7", 
    "p_home_fouls_fouls_last_7", "p_away_goals_scored_last_7", 
    "p_away_shots_conceded_last_7", "p_away_points_last_7"
]]

X_test_scaled_new = X_test_scaled[[
    "p_home_goals_scored_last_7", "p_home_shots_taken_last_7", 
    "p_home_fouls_fouls_last_7", "p_away_goals_scored_last_7", 
    "p_away_shots_conceded_last_7", "p_away_points_last_7"
]]

# %%
tree = DecisionTreeRegressor(max_depth=3)
tree.fit(X_train_scaled_new, y_train)
# Out:
# DecisionTreeRegressor(max_depth=3)

# %%
pred = tree.predict(X_test_scaled_new)

print("MAE", mean_absolute_error(pred, y_test))
print("RMSE", mean_squared_error(pred, y_test, squared=False))
print("R2 score", tree.score(X_test_scaled_new, y_test))
# Out:
# MAE 0.9183002912282585
# RMSE 1.1779747570492076
# R2 score 0.0332635622320796
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %% [markdown]
# # Descision Tree - Regressor - Away Goals

# %%
features = rolling_stats.select_dtypes("number").drop(columns=["FTHG", "FTAG"])
target = rolling_stats["FTAG"]

X_train, X_test, y_train, y_test = train_test_split(features, target, random_state = 0)

# %%
scaler = MinMaxScaler()
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
tree = DecisionTreeRegressor(max_depth=3)
tree.fit(X_train_scaled, y_train)
# Out:
# DecisionTreeRegressor(max_depth=3)

# %%
pred = tree.predict(X_test_scaled)

print("MAE", mean_absolute_error(pred, y_test))
print("RMSE", mean_squared_error(pred, y_test, squared=False))
print("R2 score", tree.score(X_test_scaled, y_test))
# Out:
# MAE 0.709696468624136
# RMSE 0.9044023511929057
# R2 score 0.4301514001232617
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %% [markdown]
# # KNN - Regressor

# %%
knn = KNeighborsRegressor(n_neighbors = 2)
knn.fit(X_train_scaled, y_train)
# Out:
# KNeighborsRegressor(n_neighbors=2)

# %%
knn.score(X_test_scaled, y_test)
# Out:
# 0.18095877728794896

# %%
# Test with updated features

# %%
knn = KNeighborsRegressor(n_neighbors = 250)
knn.fit(X_train_scaled_new, y_train)
# Out:
# KNeighborsRegressor(n_neighbors=250)

# %%
knn.score(X_test_scaled_new, y_test)
# Out:
# -0.3634039865877434

# %% [markdown]
# # KNN - Classifier

# %%
knn = KNeighborsClassifier(n_neighbors = 2)
knn.fit(X_train_cl_scaled, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=2)

# %%
knn.score(X_test_cl_scaled, y_test_cl)
# Out:
# 0.14623655913978495

# %% [markdown]
# # Decision Tree - Classifier

# %%
# Train / Test Split

# %%
features_cl = rolling_stats.select_dtypes("number").drop(columns=["FTHG", "FTAG", "FTR_num"])
target_cl = rolling_stats["FTR_num"]

X_train_cl, X_test_cl, y_train_cl, y_test_cl = train_test_split(features_cl, target_cl, random_state = 0)

# %%
# Scaling

scaler = MinMaxScaler()
scaler.fit(X_train_cl)
X_train_cl_scaled = scaler.transform(X_train_cl)
X_test_cl_scaled = scaler.transform(X_test_cl)

# %%
tree = DecisionTreeClassifier(max_depth=71)

# %%
tree.fit(X_train_cl_scaled, y_train_cl)
# Out:
# DecisionTreeClassifier(max_depth=71)

# %%
pred = tree.predict(X_test_cl)

print("Accuracy:", accuracy_score(y_test_cl, pred))
print(classification_report(y_test_cl, pred))
# Out:
# Accuracy: 0.45161290322580644
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00       358
#            2       0.45      1.00      0.62       633
#            3       0.00      0.00      0.00       404
#
#     accuracy                           0.45      1395
#    macro avg       0.15      0.33      0.21      1395
# weighted avg       0.21      0.45      0.28      1395
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(

# %% [markdown]
# # Logistic Regression

# %%
features_cl = rolling_stats.select_dtypes("number").drop(columns=["FTHG", "FTAG", "FTR_num"])
target_cl = rolling_stats["FTR_num"]

X_train_cl, X_test_cl, y_train_cl, y_test_cl = train_test_split(features_cl, target_cl, random_state = 0)

# %%
# Scaling

scaler = MinMaxScaler()
scaler.fit(X_train_cl)
X_train_cl_scaled = scaler.transform(X_train_cl)
X_test_cl_scaled = scaler.transform(X_test_cl)

# %%
log_reg = LogisticRegression()

# %%
log_reg.fit(X_train_cl_scaled, y_train_cl)
# Out:
# LogisticRegression()

# %%
pred = log_reg.predict(X_test_scaled)

print("Accuracy:", accuracy_score(y_test, pred))
print(classification_report(y_test, pred))
# Out:
# Accuracy: 0.21577060931899641
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       266
#            1       0.40      0.01      0.03       446
#            2       0.27      0.75      0.40       352
#            3       0.08      0.16      0.11       195
#            4       0.00      0.00      0.00        86
#            5       0.00      0.00      0.00        37
#            6       0.00      0.00      0.00        10
#            7       0.00      0.00      0.00         3
#
#     accuracy                           0.22      1395
#    macro avg       0.09      0.12      0.07      1395
# weighted avg       0.21      0.22      0.12      1395
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
